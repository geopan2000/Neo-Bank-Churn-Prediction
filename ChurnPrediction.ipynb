# %% [markdown]
# #Neo Bank Churn Prediction

# %%
# Clone the GitHub repository
# !git clone https://github.com/geopan2000/Neo-Bank-Churn-Prediction.git

# Change directory to the cloned repository
# %cd ChurnPrediction
# Out:
# Cloning into 'Neo-Bank-Churn-Prediction'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 626.51 KiB | 1.99 MiB/s, done.
# [Errno 2] No such file or directory: 'ChurnPrediction'
# /content

# %%
# prompt: mount my drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import xgboost as xgb

# !pip install scikit-optimize
# !pip install shap
from skopt import BayesSearchCV
from skopt.space import Real, Integer

from sklearn.model_selection import KFold
from skopt import BayesSearchCV
from skopt.space import Real, Integer
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from google.colab import files
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 5.2 MB/s eta 0:00:00
# ...

# %%
train_2008 = pd.read_parquet('/content/drive/MyDrive/Neo bank churn prediction/data/train_2008.parquet')
train_2008.to_csv('train_2008.csv', index=False)
train_2008.head(50)
# Out:
#       Id  customer_id  interest_rate            name    country date_of_birth  \
# 0      1            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 1      6            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 2     16            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 3     31            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 4     50            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 5    102            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 6    134            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 7    171            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 8    211            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 9    254            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# 10   302            1            3.5  Yolanda Parker  Lithuania    1954-07-10
# ...
